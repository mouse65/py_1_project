# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
hh_data_df = pd.read_csv('data/dst-3.0_16_1_hh_database.csv',sep = ';') # чтение первоначальной таблицы csv

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
#display(hh_data_df.head()) # первые строки
display(hh_data_df.tail(7)) # последние строки ( 7 строк)
# Out:
#                                        Пол, возраст           ЗП  \
# 44737   Мужчина ,  31 год , родился 8 сентября 1987   70000 руб.
# 44738     Мужчина ,  37 лет , родился 12 марта 1982  150000 руб.
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#                                Ищет работу на должность:  \
# 44737                             Руководитель IT-отдела
# 44738                                   head of helpdesk
# 44739  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740             Системный администратор, IT-специалист
# 44741                         Аналитик данных, Математик
# 44742                                   Контент-менеджер
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
hh_data_df.info()
hh_data_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
hh_data_df.describe(include = "all")
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
hh_data_df['Образование'] = hh_data_df.apply(lambda x: 'среднее специальное' if 'Среднее специальное образование' in ' '.join(x['Образование и ВУЗ'].split(' ')[:3]) else x['Образование и ВУЗ'], axis=1)
hh_data_df['Образование'] = hh_data_df.apply(lambda x: 'среднее' if 'Среднее образование' in ' '.join(x['Образование'].split(' ')[:3]) else x['Образование'], axis=1)
hh_data_df['Образование'] = hh_data_df.apply(lambda x: 'высшее' if 'Высшее образование' in ' '.join(x['Образование'].split(' ')[:3]) else x['Образование'], axis=1)
hh_data_df['Образование'] = hh_data_df.apply(lambda x: 'неоконченное высшее' if 'Неоконченное высшее образование' in ' '.join(x['Образование'].split(' ')[:3]) else x['Образование'], axis=1)
#
hh_data_df = hh_data_df.drop(['Образование и ВУЗ'],axis=1)
print(hh_data_df['Образование'].value_counts())  # для ответа на вопрос 3.1
# Out:
# Образование
# высшее                 33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее                  559
# Name: count, dtype: int64

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
hh_data_df['Пол'] = hh_data_df.apply(lambda x: 'М' if 'Мужчина' in x['Пол, возраст'] else x['Пол, возраст'], axis=1)
hh_data_df['Пол'] = hh_data_df.apply(lambda x: 'Ж' if 'Женщина' in x['Пол'] else x['Пол'], axis=1)
#
hh_data_df['Возраст'] = hh_data_df.apply(lambda x:  ''.join(''.join(x['Пол, возраст'].split(',')[1:2]).split()[:1]), axis=1)
#
print(hh_data_df['Пол'].value_counts('Ж'))                     # к вопросу 3.2
hh_data_df['Возраст'] = hh_data_df['Возраст'].astype(int)
print(hh_data_df['Возраст'].mean())
# Out:
# Пол
# М    0.809293
# Ж    0.190707
# Name: proportion, dtype: float64
# 32.19674146254246

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь
def get_experience(arg):
    """[Функция приведения отображения опыта работы к общему показателю в месяцах]

    Args:
        arg ([str]): [На вход получает значение признака 'Опыт работы']

    Returns:
        [int]: [Кол-во месяцев]
    """
    if arg is np.nan or arg == 'Не указано':
        return None                       # Возвращаем None чтоб не бло ошибок при построении графиков

    # Задаем ключевые слова для сравнения
    year_words=['год', 'года', 'лет']
    month_words=['месяц', 'месяца', 'месяцев']

    arg_splitted = arg.split(' ')[:7] # в первых 7 словах содержится нужная информация об опыте работы
    
    # Создаем счетчики
    years = 0
    months = 0
    
    for index, item in enumerate(arg_splitted):  # [(0, 'Опыт'), (1, 'работы'), (2, '16'), (3, 'лет')] arg_splitted - это список
        if item in year_words:
            years = int(arg_splitted[index-1]) # значение в предыдущем картеже
        if item in month_words:
            months = int(arg_splitted[index-1])
    return years*12 + months
#
hh_data_df['Опыт работы (месяц)'] = hh_data_df['Опыт работы'].apply(get_experience)
months_median = hh_data_df['Опыт работы (месяц)'].median()
hh_data_df = hh_data_df.drop(['Опыт работы'],axis=1)
#
print(months_median)
# Out:
# 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь
# Список городов-миллионников:
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]
#
def get_city(args):
    """[Функция определения категории города]

    Args:
        args ([str]): [Город, переезд, командировки]

    Returns:
        [str]: [Возвращает 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" и "другие" ]
    """
    city = args.split(' , ')[0]
    if (city == 'Москва') or (city == 'Санкт-Петербург'):
        return city
    elif city in million_cities:
        return 'город миллионник'
    else:
        return 'другие'
#
hh_data_df['Город'] = hh_data_df['Город, переезд, командировки'].apply(get_city)
#  ответ на вопрос 3.4
#
k_sp=hh_data_df['Город'].value_counts()['Санкт-Петербург']  # повторение "Санкт-Петербург" в столбце
k_sp_1 = k_sp/44744
print(k_sp_1)
#
print(round(hh_data_df['Город'].value_counts(normalize=True)['Санкт-Петербург']*100))# относительное количество 'Санкт-Петербург' в столбце                   
#
# Out:
# 0.11033881637761488
# 11

# %%
def ready_to_move(args):
    """[Функция формирования данных для признака Готовность к переезду]

    Args:
        args ([str]): [Город, переезд, командировки]

    Returns:
        [bool]: [готов = True, не готов = False]
    """
    result = None
    if ('не готов к переезду' in args) or ('не готова к переезду' in args) or ('не хочу переезжать' in args):
        result = False  
    elif 'хочу' in args:
        return True
    else:
        result = True
    return result


hh_data_df['Готовность к переезду'] = hh_data_df['Город, переезд, командировки'].apply(ready_to_move)

# %%
def ready_to_trip(args):
# варианты готовности к командировкам
    list_var = ['готов к командировкам', 'готова к командировкам', 'готов к редким командировкам', 'готова к редким командировкам']
    list_var_no = ['не готов к командировкам', 'не готова к командировкам']
    """[Функция формирования данных для признака Готовность к командировккам]

    Args:
        args ([str]): [Город, переезд, командировки]

    Returns:
        [bool]: [готов = True, не готов = False]
    """
    result = None
    for i, v in enumerate(list_var):
         if v in args:
             result = True
             break 
         else:
             result = False
#
    for i, v in enumerate(list_var_no):
         if v in args:
             result = False
             break
#
    return result
hh_data_df['Готовность к командировкам'] = hh_data_df['Город, переезд, командировки'].apply(ready_to_trip)
# к вопросу 3.4
print(round(hh_data_df[hh_data_df['Готовность к переезду'] & hh_data_df['Готовность к командировкам']].shape[0]/hh_data_df.shape[0]*100))
#print(round(hh_data_df['Готовность к командировкам'].value_counts(normalize=True)[True]*100))
hh_data_df = hh_data_df.drop(['Город, переезд, командировки'],axis=1)
# Out:
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь
employments = ['полная занятость', 'частичная занятость',
              'проектная работа', 'волонтерство', 'стажировка']
#
charts = ['полный день', 'сменный график', 
         'гибкий график', 'удаленная работа',
         'вахтовый метод']
for employments, charts in zip(employments,charts):# цикл прохода по каждому элементу двух списков
# заполнение новых столбцов с именами из списка employments
    hh_data_df[employments] = hh_data_df['Занятость'].apply(lambda x: employments in x)
# заполнение новых столбцов с именами из списка charts
    hh_data_df[charts] = hh_data_df['График'].apply(lambda x: charts in x)
# ответы на вопросы 3.5
print(hh_data_df[hh_data_df['проектная работа'] & hh_data_df['волонтерство']].shape[0])
print(hh_data_df[hh_data_df['вахтовый метод'] & hh_data_df['гибкий график']].shape[0])
# удаляем признаки 'занятость' и 'график'
hh_data_df = hh_data_df.drop(['Занятость'],axis=1)
hh_data_df = hh_data_df.drop(['График'],axis=1)
#
#display (hh_data_df)
# Out:
# 436
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь
exchange_df = pd.read_csv('data/Exchange_Rates.csv',sep = ',') # чтение первоначальной таблицы csv
display(exchange_df)
# Out:
#      currency per      date   time    close  vol  proportion
# 0         USD   D  29/12/17  00:00  57.6291    0           1
# 1         USD   D  30/12/17  00:00  57.6002    0           1
# 2         USD   D  31/12/17  00:00  57.6002    0           1
# 3         USD   D  01/01/18  00:00  57.6002    0           1
# 4         USD   D  02/01/18  00:00  57.6002    0           1
# ...       ...  ..       ...    ...      ...  ...         ...
# 5659      AZN   D  02/12/19  00:00  37.7729    0           1
# 5660      AZN   D  03/12/19  00:00  37.9662    0           1
# 5661      AZN   D  04/12/19  00:00  37.8073    0           1
# 5662      AZN   D  05/12/19  00:00  37.8396    0           1
# 5663      AZN   D  06/12/19  00:00  37.6148    0           1
#
# [5664 rows x 7 columns]

# %%
def get_salary_num(arg):
    salary = float(arg.split(' ')[0]) # берем 0-й элемент признака 'ЗП', т.е. численное выражение зарплаты.
    return salary

def get_salary_currency(arg):
    currency_dict = {
        'USD':'USD', 'KZT': 'KZT',
        'грн': 'UAH', 'белруб': 'BYN',
        'EUR': 'EUR', 'KGS': 'KGS',
        'сум': 'UZS', 'AZN': 'AZN'
        }
    curr = arg.split(' ')[1].replace('.', '') # замена в 1-м элементе признака 'ЗП' . на ''
    if curr == 'руб':
        return 'RUB'
    else:
        return currency_dict[curr] # возвращаем значение названия валюты из словаря currency_dict
#
exchange_df['date'] = pd.to_datetime(exchange_df['date']).dt.date # перевод даты в станд. вид в таблице курсов
hh_data_df['Обновление резюме'] = pd.to_datetime(hh_data_df['Обновление резюме']).dt.date #перевод даты в станд. вид в таблице hh
#
hh_data_df['ЗП (tmp)'] = hh_data_df['ЗП'].apply(get_salary_num)
hh_data_df['Курс (tmp)'] = hh_data_df['ЗП'].apply(get_salary_currency)

merged = hh_data_df.merge(
    exchange_df,
    left_on=['Курс (tmp)', 'Обновление резюме'],
    right_on=['currency', 'date'],
    how='left'
)
merged['close'] = merged['close'].fillna(1) # все пропуски заменяются на 1
merged['proportion'] = merged['proportion'].fillna(1)
# новая колонка ЗП , переведенная в рубли
hh_data_df['ЗП (руб)'] = merged['close']* merged['ЗП (tmp)'] / merged['proportion'] # зп в валюте умножаем на курс и делим на пропорцию
hh_data_df = hh_data_df.drop(['ЗП','ЗП (tmp)','Курс (tmp)'], axis=1)
# ответ на вопрос 3.6
print(round(hh_data_df['ЗП (руб)'].median()/1000))
#
display(exchange_df)
display(hh_data_df)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14900\2469442447.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   exchange_df['date'] = pd.to_datetime(exchange_df['date']).dt.date # перевод даты в станд. вид в таблице курсов
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14900\2469442447.py:19: UserWarning: Parsing dates in %d.%m.%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   hh_data_df['Обновление резюме'] = pd.to_datetime(hh_data_df['Обновление резюме']).dt.date #перевод даты в станд. вид в таблице hh
# 59
#      currency per        date   time    close  vol  proportion
# 0         USD   D  2017-12-29  00:00  57.6291    0           1
# 1         USD   D  2017-12-30  00:00  57.6002    0           1
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
fig_1 = px.histogram(
    hh_data_df, 
    x="Возраст",
    title = 'Распределение соискателей по возрасту', 
    marginal='box'
)
#fig_1.show(renderer="png",
#     width=700,
#     height=450,
#     scale=None
#)
fig_1.show('png')

#

# %% [markdown]
# ваши выводы по графику здесь
#   распределение возраста среди соискателей напоминает логнормальное распределение. Мода распределения, как видно из графика,
#   соответствует ~30 годам. Таких соискателей 2834 на общее число 44744, что составляет 6.3%. Предельные значения возраста 14
#    и 100 лет. От 14 до 50 лет - возраст большинства соискателей,что
#    видно визуально из lower fence и upper fence коробчатой диаграммы. Чисто статитстически "аномалиями" можно считать существенно большие чем 50 возраста, которые в значительном количестве видны на box диаграмме справа.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
fig_2 = px.histogram(
      hh_data_df, 
      x='Опыт работы (месяц)',
      title = 'Распределение опыта работы соискателей' ,
      marginal='box'
)
fig_2.show('png')

# %% [markdown]
# Максимальное количество соискаталей (1414 человек) имеют опыт работы 80-84 месяца (мода). Признак имеет распределение от 0 до 1188 месяцев. Из box схемы хорошо видно, что распределение от нижней до верхней границы (0-300 мес.) включает подавляющее большинство соискателей. "Аномальными"
# можно считать значения опыта выше верхней границы по коробчатой диаграмме ( ~ 300 мес, что составляет ~25 лет).

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
# из - за существенных выбрасов, достигающих 25 млн рублей стоит вначале прологарифмировать признак ЗП
import math
hh_data_df['log(ЗП (руб))'] = hh_data_df['ЗП (руб)'].apply(lambda x_1: math.log(x_1))
fig_3 = px.histogram(
      hh_data_df, 
      x = 'log(ЗП (руб))',
      title = 'Распределение зарплаты соискателей' ,
      marginal='box'
)
fig_3.show('png')

# %% [markdown]
# Представлена диаграмма логорифмического распределения зарплаты соискателей. По оси x отложено значение натурального логарифма зарплаты ln('ЗП (руб)'). Распределение на вид идеально повторяет логнормальное распределение, однако с большим количеством 'пропусков'. Из box диаграммы сверху хорошо видно, что предельные значения зарплаты 0 (минимум) и e**17= 23 млн. руб. И то и другое значение , повидимому можно считать "выбросами", появившимеся здесь по неизвестной причине. Аномальными можно считать зарплаты весьма незначительные (<8000 р), которые находятся левее lower fence и сильно большие (>380 000 р.), правее upper fence.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
temp_1 = hh_data_df['ЗП (руб)'] < 1000000
mask_he = (hh_data_df['Образование'] == 'высшее') & temp_1
mask_b = (hh_data_df['Образование'] == 'неоконченное высшее') & temp_1
mask_me = (hh_data_df['Образование'] == 'среднее') & temp_1
mask_sm = (hh_data_df['Образование'] == 'среднее специальное') & temp_1
#
hh_data_df_he = hh_data_df[mask_he] # отфильтрованная таблица по высшему образованию
hh_data_df_b = hh_data_df[mask_b] # 
hh_data_df_me = hh_data_df[mask_me] # 
hh_data_df_sm = hh_data_df[mask_sm] # 
#    
salary_he = hh_data_df_he['ЗП (руб)'].median() # медианная зарплата по высшему образованию
salary_b = hh_data_df_b['ЗП (руб)'].median() #
salary_me = hh_data_df_me['ЗП (руб)'].median() #
salary_sm = hh_data_df_sm['ЗП (руб)'].median() #
#
#   ---- построение bar диаграммы
#
education = ['высшее', 'неок. высшее', 'среднее', '  среднее спец.']
values = [salary_he, salary_b, salary_me, salary_sm]
plt.bar(education, values)
plt.title("Зависимость медианной зарплаты от уровня образования")
plt.ylabel("зарплата")
plt.show()

# %% [markdown]
# Прослеживается вполне логичная связь зарплаты и образования. ЗП пропорционально уменьшается от высшего к среднему образованию.
# Среднее и среднее специальное по зарплате совершенно одинаковы. Уровень образования безусловно важен для прогнозирования ЗП. Однако, в смысле зарплаты среднее и среднее спец. можно объединить в один столбец.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
box_hh_data = hh_data_df[hh_data_df['ЗП (руб)']<1000000]
fig_5 = px.box(
    data_frame=box_hh_data,
    x='Город',
    y='ЗП (руб)',
    color='Город',
    title='Распределение зарплаты по городам'
)
fig_5.show('png')

# %% [markdown]
# Медианная зарплата в Москве самая высокая (85000 р.), в Санкт-Петербурге -60000 р. Удивительно, но города миллионники и малые города
# не отличаются по медианной зарплате (40000 р). Размах по зарплате в Москве от q1 до q3 почти в 4 раза больше чем в регионах и в 3 раза больше, чем в СП. Повидимому это вызвано разнообразием сфер деятельности, в которых есть рабочие места в Москве, и существенно меньшим разнообразием в локальных городках, которые очень часто имеют градообразующие предприятия. Судя по представленным боксам две столицы имеют определяющее влияние на зарплату, в то время как другие города и даже миллионники не отличаются в этом смысле друг от друга.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь
bar_hh_data = hh_data_df.groupby(
     ['Готовность к командировкам' , 'Готовность к переезду'],
     as_index=False   
)['ЗП (руб)'].median()
fig_6 = px.bar(
     data_frame=bar_hh_data,
     y='ЗП (руб)',
     x='Готовность к переезду',
     barmode='group',
     color='Готовность к командировкам',
     title='Медианная зарплата по готовности к переезду/командировкам'
)
fig_6.show('png')

# %%
# в случае готовности к переезду (правая пара) зарплата заметно больше, что вполне логично. Зарплата неготовых к переезду, но готовых к командировкая
#тоже весьма высокая. Она всего на 6 тысяч меньше, чем готовых и к тому и к лругому. Максимальная разница в 26 тыс. рублей между не
# готовыми к перемещениям совсем и готовым на командировки и переезв весьма значительна, что говорит о ценности перемещения как фактора зарплаты.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
# построение сводной таблицы методом pivot_table
hh_data_sum = hh_data_df.pivot_table(
    values='ЗП (руб)',
    index='Возраст', #  строки
    columns='Образование', # столбцы
    aggfunc='median',
    fill_value = 0 # значение для заполнения пропусков
)
display(hh_data_sum)
#
# построение тепловой схемы
#
fig_7 = px.imshow(
    hh_data_sum,
    aspect='auto',
#    color_continuous_scale='greens',
    title=' Медианная зарплата по возрасту и образованию'
)
fig_7.show('png')
# Out:
# Образование     высшее  неоконченное высшее  среднее  среднее специальное
# Возраст
# 14            60000.00                  0.0      0.0                  0.0
# 15                0.00                  0.0  10000.0               2000.0
# 16           122582.49                  0.0      0.0              30000.0
# 17            90075.50              80000.0  44000.0              25000.0
# 18            30000.00              25000.0  35000.0              25151.0
# ...                ...                  ...      ...                  ...
# 72            75000.00                  0.0      0.0                  0.0
# 73            62500.00                  0.0      0.0                  0.0
# 76            45000.00                  0.0      0.0                  0.0
# 77            90000.00                  0.0      0.0                  0.0
# 100               0.00                  0.0      0.0              60000.0
#
# [63 rows x 4 columns]

# %% [markdown]
# Люди с высшим образованием имеют заметно выраженный максимум в зарплате (в районе 80-90 т.р.) в 40 - 49 лет. Повидимому это люди,существенно продвинувшиеся в карьере к этому возрасту. Следующий максимум  в высшем образовании соотв. уже предыдущему поколению людей, строивших карьеру (68 - 73 года). Они, повидимому, достигли высокого проф. уровня и/или руковод. должностей. Одиночные желтые или синие линии на графиках всех уровней образования - это наверное некие нестандартные запросы, чисто математически пологаемые выбросами. Люди со средним образованием имеют весьма скромные запросы и возраст этих анкет обрывается на 60 - ти годах, что указывает на пенсию. Люди с не оконч. высшим тоже склонны просто уходить на пенсию, однако некий карьерный максимум в районе 42-50 лет у них всеже просматривается. Соискатели со средним спец. образованием также имеют весьма скромные запросы, однако продолжают работать и на пенсии.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь
#
#    библиотека Matplotlib
hh_scatter = hh_data_df.copy()
hh_scatter['Опыт работы (месяц)'] = hh_scatter['Опыт работы (месяц)']/12 # перевод месяцев в годы
#
fig_8 = plt.figure(figsize=(8, 5))
axes = fig_8.add_axes([0, 0, 1, 1])
sns.lineplot(x=[0,100],y=[0,100])  # прямая y = x
axes.scatter(
    x=hh_scatter['Возраст'],
    y=hh_scatter['Опыт работы (месяц)'],
    s=3,
    marker='o',
    c = 'blue'
);
axes.set_title('Зависимость опыта работы от возраста')
axes.set_xlabel('Возраст')
axes.set_ylabel('Опыт (годы)')
#
#  ответ на вопрос 4.8
print(hh_scatter[hh_scatter['Опыт работы (месяц)'] > hh_scatter['Возраст']].shape)
# Out:
# (7, 25)

# %% [markdown]
# Всего несколько точек, в которых стаж больше или равен возрасту. Это явно точки недостоверные. Точки ниже прямой y=x по верхней кромке также образуют заметную прямую линию. Если ее мысленно провести, то она пересекает ос х в районе 18 лет, что соответствует логичному началу трудовой деятельности. После возраств ~ 38 лет, количество соискателей с нулевым и низким опытом заметно сокращается.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
#      распределение  соискателей на удаленную работу по возрастам
#display(hh_data_df.info())
fig_9 = px.histogram(
    hh_data_df[hh_data_df['удаленная работа']], 
    x="Возраст",
    title = 'Распределение соискателей по возрасту для удаленной работы', 
    marginal='box'
)
fig_9.show('png')
#
#  доля (%) соискателей, предендующих на удаленную работу в зав. от образования
#
mask_he = (hh_data_df['Образование'] == 'высшее')
mask_b  = (hh_data_df['Образование'] == 'неоконченное высшее')
mask_me = (hh_data_df['Образование'] == 'среднее')
mask_sm = (hh_data_df['Образование'] == 'среднее специальное')
#
hh_data_df_he = hh_data_df[mask_he] # отфильтрованные таблицы по образованию
hh_data_df_b  = hh_data_df[mask_b] # 
hh_data_df_me = hh_data_df[mask_me] # 
hh_data_df_sm = hh_data_df[mask_sm] #
# относительное количество соискателей, ищущих удаленную работу
dist_he = list(hh_data_df_he['удаленная работа'].value_counts(normalize=True)*100) # с высшим обр.
dist_b  = list(hh_data_df_b ['удаленная работа'].value_counts(normalize=True)*100) # с неок. высшим
dist_me = list(hh_data_df_me['удаленная работа'].value_counts(normalize=True)*100) # со средним образованием
dist_sm = list(hh_data_df_sm['удаленная работа'].value_counts(normalize=True)*100) # со средним спец. образованием
#
#   ---- построение bar диаграммы
#
education = ['высшее', 'неок. высшее', 'среднее', '  среднее спец.']
values = [dist_he[1], dist_b[1], dist_me[1], dist_sm[1]]
plt.bar(education, values)
plt.title("Доля соискателей на удаленную работу в зависимости от образования")
plt.ylabel(" % соискателей")
plt.show()

# %% [markdown]
# 1. График распределения по возрастам только для удаленной работы. Не видно сколь нибудь заметного отличия от распределения по возрастам в первом задании (fig_1). Такая же мода в 30 лет, хотя казалось здесь должно быть "омоложение" соискателей, но не  подтвердилось.
#
# 2. Столбчатая диаграмма доли соискателей на удаленную работу в зависимости от уровня образования. Трудно объяснимая зависимость. Почему-то максимальная доля (41%) соответствует неоконченному высшему образованию, на втором месте (38%) люди со среднем образованием,
# 33% - с высшем образованием, 28% - со средним специальным образованием. Можно предположить, что люди со средним и неок. высшим имеют минимальную специализацию, то есть фактически только общее образование. Соответственно такие люди менее привязаны к конкретному месту работы и в большей степени интересуются удаленной работой, возможно различного профиля. Люди же с высшим и средним специальным имеют конкретную профессиональную специализацию и, поэтому, ассоциируют себя с конкретными рабочими местами по понятным им специальностям. Поэтому они в меньшей степени склонны к дисстанционной работе.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
#
dupl_columns = list(hh_data_df.columns) # список всех столбцов
mask = hh_data_df.duplicated(subset=dupl_columns) # собераем все столбцы
hh_duplicates = hh_data_df[mask]
hh_data_df = hh_data_df.drop_duplicates()  # удаление дубликатов
print(f'Число найденных дубликатов: {hh_duplicates.shape[0]}')
# Out:
# Число найденных дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
cols_null = hh_data_df.isnull().sum()  # количество пропусков во всех столбцах
display(cols_null)
# Out:
# Пол, возраст                         0
# Ищет работу на должность:            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# полная занятость                     0
# полный день                          0
# частичная занятость                  0
# сменный график                       0
# проектная работа                     0
# гибкий график                        0
# волонтерство                         0
# удаленная работа                     0
# стажировка                           0
# вахтовый метод                       0
# ЗП (руб)                             0
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь
hh_data_df = hh_data_df.dropna(subset=['Последнее/нынешнее место работы','Последняя/нынешняя должность'])
#
# перезаписываем NaN на медианные значения с помощью метода .fillna
hh_data_df['Опыт работы (месяц)'] = hh_data_df['Опыт работы (месяц)'].fillna(hh_data_df['Опыт работы (месяц)'].median())
print(hh_data_df['Опыт работы (месяц)'].mean())
print(hh_data_df.info())
# Out:
# 114.35777573405711
# <class 'pandas.core.frame.DataFrame'>
# Index: 44581 entries, 0 to 44743
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44581 non-null  object
#  1   Ищет работу на должность:        44581 non-null  object
#  2   Последнее/нынешнее место работы  44581 non-null  object
#  3   Последняя/нынешняя должность     44581 non-null  object
#  4   Обновление резюме                44581 non-null  object
#  5   Авто                             44581 non-null  object
#  6   Образование                      44581 non-null  object
#  7   Пол                              44581 non-null  object
#  8   Возраст                          44581 non-null  int32
#  9   Опыт работы (месяц)              44581 non-null  float64
#  10  Город                            44581 non-null  object
# ...

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
solary_more_1 = hh_data_df['ЗП (руб)'] > 1000000
solary_less_1 = hh_data_df['ЗП (руб)'] < 1000
drop_lines = hh_data_df[solary_more_1 | solary_less_1]
hh_data_df = hh_data_df.drop(drop_lines.index)
print(drop_lines.shape[0])
# Out:
# 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
experience_age = hh_data_df[hh_data_df['Опыт работы (месяц)']/12 >= hh_data_df['Возраст']]
hh_data_df = hh_data_df.drop(experience_age.index)
print(experience_age.shape[0])
# Out:
# 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь
#   лог распределение с п верт линиями в местах 3 - х сигм.
#
ig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_age = np.log(hh_data_df['Возраст']) # логарифмируем признак 'Возраст'
histplot = sns.histplot(log_age, bins=30, ax=ax)
histplot.axvline(log_age.mean(), color='k', lw=2)  #.axvline строит вертикальные линии
histplot.axvline(log_age.mean() + 4 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean() - 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Логарифимеское распределение возраста');
#

# %%
#  --- диаграмма распределения outliers_z_score_mod
#
def outliers_z_score_mod(data, feature, left=3, right=3, log_scale=False):
    if log_scale:
        x = np.log(hh_data_df[feature])
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned
#
outliers, cleaned =outliers_z_score_mod(hh_data_df, 'Возраст', right=4, log_scale=True)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
print ('записи для возможного удаления')
display(outliers)
#
# Out:
# Число выбросов по методу z-отклонения: 3
# Результирующее число записей: 44482
# записи для возможного удаления
#                                      Пол, возраст  \
# 31137     Мужчина ,  15 лет , родился 11 мая 2004
# 32950     Мужчина ,  15 лет , родился 1 июня 2003
# 33654  Мужчина ,  100 лет , родился 1 января 1919
#
#             Ищет работу на должность: Последнее/нынешнее место работы  \
# 31137  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
# 32950                 Тестировщик игр                        OOO ЖМЫХ
# 33654            Frontend-разработчик                       Freelance
#
#          Последняя/нынешняя должность Обновление резюме        Авто  \
# 31137  Менеджер по работе с клиентами        2019-04-06  Не указано
# 32950                  Тестировщик ПО        2019-04-09  Не указано
# 33654            Frontend-разработчик        2019-04-19  Не указано
#
#                Образование Пол  Возраст  Опыт работы (месяц)  ...  \
# ...

# %% [markdown]
# Логарифмическое распределение возраста на вид довольно сносно напоминает логнормальное распределение с учетом того, что
# некоторая ассиметрия заметна в правую сторону ( в сторону увеличения возраста). Судя по графику распределения в статистическом смысле "выбросами" можно считать те возраста, которые не попадают в 3 сигма слева и 4 сигма справа, то есть не соответствуют промежутку приблизительно от 16 до 80 лет. Таковых оказалось всего 3.
